# %% [markdown]
# 24/09 ~ 12까지의 코인데이터를 시각화하는 노트북

# %%
# 1. 필요한 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# 2. 데이터 불러오기
df = pd.read_csv("../src/data/filtered_BTC_data_2024_Sep_Dec.csv")

# %%
# 3. 날짜 컬럼을 datetime 형식으로 변환
df['캔들 기준 시각(UTC기준)'] = pd.to_datetime(df['캔들 기준 시각(UTC기준)'])

# %%
# 4. 시계열 그래프 그리기 (종가 기준)
plt.figure(figsize=(12, 6))
plt.plot(df['캔들 기준 시각(UTC기준)'], df['종가'], color='blue', linewidth=1)
plt.title("Bitcoin Price (Close) from Sep to Dec 2024", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Price (KRW)", fontsize=12)
plt.grid(True)
